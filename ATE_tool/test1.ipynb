# %%
import mongoConnect

# %%
db = mongoConnect.AteDbAgent(db_address="mongodb://wjl:espressif_wjl@192.168.7.171/cepq_test")

# %%
db.list_tester_info("2021-08-15 10:00:00", "2021-08-15 20:00:00")
# Out:
# tmin:  1628992800
# tmax:  1629028800
# fname:  ForeHope_T2100-5012_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.002_FT1_R1_FH_ESP32_D0WD_FT_J750HD_REV473_20210815032730.std.zip
# fname:  ForeHope_T2100-5008_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.003_FT1_R1_FH_ESP32_D0WD_FT_J750HD_REV473_20210814054429.std.zip
# fname:  ForeHope_T2100-5012_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.002_FT1_R2_FH_ESP32_D0WD_FT_J750HD_REV473_20210815032730.std.zip
# fname:  ForeHope_T2100-5010_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.004_FT1_R1_FH_ESP32_D0WD_FT_J750HD_REV473_20210814122835.std.zip
# fname:  ForeHope_T2100-5008_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.003_FT1_R2_FH_ESP32_D0WD_FT_J750HD_REV473_20210814054429.std.zip
# fname:  ForeHope_T2100-5008_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.003_QA1_Q0_FH_ESP32_D0WD_QA_J750HD_REV473_20210814054429.std.zip
# ...

# %%
db.list_tester_info("2021-08-15 10:00:00", "2021-08-17 20:00:00")
# Out:
# tmin:  1628992800
# tmax:  1629201600
# fname:  ForeHope_T2100-5012_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.002_FT1_R1_FH_ESP32_D0WD_FT_J750HD_REV473_20210815032730.std.zip
# fname:  ForeHope_T2100-5008_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.003_FT1_R1_FH_ESP32_D0WD_FT_J750HD_REV473_20210814054429.std.zip
# fname:  ForeHope_T2100-5012_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.002_FT1_R2_FH_ESP32_D0WD_FT_J750HD_REV473_20210815032730.std.zip
# fname:  ForeHope_T2100-5010_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.004_FT1_R1_FH_ESP32_D0WD_FT_J750HD_REV473_20210814122835.std.zip
# fname:  ForeHope_T2100-5008_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.003_FT1_R2_FH_ESP32_D0WD_FT_J750HD_REV473_20210814054429.std.zip
# fname:  ForeHope_T2100-5008_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.003_QA1_Q0_FH_ESP32_D0WD_QA_J750HD_REV473_20210814054429.std.zip
# ...

# %%
db.list_tester_info("2021-08-15 10:00:00", "2021-08-17 20:00:00")
# Out:
# tmin:  1628992800
# tmax:  1629201600
# fname:  ForeHope_T2100-5012_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.002_FT1_R1_FH_ESP32_D0WD_FT_J750HD_REV473_20210815032730.std.zip
# fname:  ForeHope_T2100-5008_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.003_FT1_R1_FH_ESP32_D0WD_FT_J750HD_REV473_20210814054429.std.zip
# fname:  ForeHope_T2100-5012_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.002_FT1_R2_FH_ESP32_D0WD_FT_J750HD_REV473_20210815032730.std.zip
# fname:  ForeHope_T2100-5010_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.004_FT1_R1_FH_ESP32_D0WD_FT_J750HD_REV473_20210814122835.std.zip
# fname:  ForeHope_T2100-5008_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.003_FT1_R2_FH_ESP32_D0WD_FT_J750HD_REV473_20210814054429.std.zip
# fname:  ForeHope_T2100-5008_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.003_QA1_Q0_FH_ESP32_D0WD_QA_J750HD_REV473_20210814054429.std.zip
# ...

# %%
db.list_tester_info("2021-09-01 10:00:00", "2021-09-17 20:00:00")
# Out:
# tmin:  1630461600
# tmax:  1631880000
# fname:  ForeHope_T2100-5008_ESP32-D0WD-ATFB00_N4RA16.00-MTK_LXT2132N011-D004_FT1_R1_FH_ESP32_D0WD_FT_J750HD_REV482_20210903021940.std.zip
# fname:  ForeHope_T2100-5008_ESP32-D0WD-ATFB00_N4RA16.00-MTK_LXT2132N011-D004_FT1_R2_FH_ESP32_D0WD_FT_J750HD_REV482_20210903025647.std.zip
# 15:43:32 - [INFO] ===========
# 15:43:32 - [INFO] Lot No: N4RA16.00-MTK
# 15:43:32 - [INFO] OSAT  : FH
# 15:43:32 - [INFO] LotSize: 0
# 15:43:32 - [INFO] ProgramVersion: FH_ESP32_D0WD_FT_J750HD_REV482
# 15:43:32 - [INFO] TesterType: J750
# 15:43:32 - [INFO] TesterNo: T2100-5008
# 15:43:32 - [INFO] ---------
# 15:43:32 - [INFO] FT1_R1; start: 03/09/2021 10:35; stop: 03/09/2021 10:55; time(hour): 0.34; interval: N/A; num: 587
# 15:43:32 - [INFO] --------
# 15:43:32 - [INFO] ===========
# 15:43:32 - [INFO] Lot No: N4RA16.00-MTK
# 15:43:32 - [INFO] OSAT  : FH
# 15:43:32 - [INFO] LotSize: 0
# 15:43:32 - [INFO] ProgramVersion: FH_ESP32_D0WD_FT_J750HD_REV482
# ...

# %%
db.list_tester_info("2021-08-10 10:00:00", "2021-09-15 20:00:00")
# Out:
# tmin:  1628560800
# tmax:  1631707200
# fname:  ForeHope_T2100-5012_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.002_FT1_R0_FH_ESP32_D0WD_FT_J750HD_REV473_20210813233821.std.zip
# fname:  ForeHope_T2100-5008_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.003_FT1_R0_FH_ESP32_D0WD_FT_J750HD_REV473_20210814054429.std.zip
# fname:  ForeHope_T2100-5010_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.004_FT1_R0_FH_ESP32_D0WD_FT_J750HD_REV473_20210814122835.std.zip
# fname:  ForeHope_T2100-5012_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.002_FT1_R1_FH_ESP32_D0WD_FT_J750HD_REV473_20210815032730.std.zip
# fname:  ForeHope_T2100-5008_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.003_FT1_R1_FH_ESP32_D0WD_FT_J750HD_REV473_20210814054429.std.zip
# fname:  ForeHope_T2100-5012_ESP32-D0WD-ATFB00_N4PP06.00-MTK_LXT2130N001-D002.002_FT1_R2_FH_ESP32_D0WD_FT_J750HD_REV473_20210815032730.std.zip
# ...
